# %% [markdown]
# # DS5K
# ## Project 3: Using ML to Predict Illegal U.S. Southwest Cross-Border Activity

# %% [markdown]
# '''
# Hi team,
# I am thinking about conducting my ML project based on U.S. southwestern illegal border activity. Specifically, my intent would be to map out previous years' land-based border activity (since FY 2017) and use ML to predict where future cross-border activity would be most prevalent and at what times of the year. My overall goal would be to map out trends in illegal border activity to assist with coordinating U.S. Customs and Border Protection response planning.
# Data sets for each year:
# U.S. Border Patrol Southwest Border Apprehensions by Sector | U.S. Customs and Border Protection (cbp.gov)
# https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters/usbp-sw-border-apprehensions
# FY 2021 (October 1, 2020 - March 31, 2021)
#
# U.S. Border Patrol Southwest Border Apprehensions by Sector Fiscal Year 2020 | U.S. Customs and Border Protection (cbp.gov)
# https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2020
# FY 2020 (October 1, 2019 - September 30, 2020)
#
# U.S. Border Patrol Southwest Border Apprehensions by Sector Fiscal Year 2019 | U.S. Customs and Border Protection (cbp.gov)
# https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2019
# FY 2019 (October 1, 2018 - September 30, 2019)
#
# U.S. Border Patrol Southwest Border Apprehensions by Sector FY2018 | U.S. Customs and Border Protection (cbp.gov)
# https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions
# FY 2018 (October 1, 2017 - September 30, 2018)
#
# U.S. Border Patrol Southwest Border Apprehensions by Sector FY2017 | U.S. Customs and Border Protection (cbp.gov)
# https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions-fy2017
# FY 2017 (October 1, 2016 - September 30, 2017)
#
# Please let me know if this project would be broad/specific enough for the intended ML project. I am more than happy to take any suggestions or recommendations you have.
# Thank you for your time, see you tomorrow for class.
#
#
# @615008 Interesting project! As you begin EDA and reviewing the data look for   elements present that you can 'predict' (ie. months when crossings occur, days when crossings occur, etc. ). Look for correlations, etc.
# '''
#
# "This predictor seems to be highly associated with this outcome..."
#
# USBP and OFO official year end reporting for FY20; USBP and OFO end of month reporting for FY21TD. Data is current as of 7/6/21.

# %% [markdown]
# # sklearn
#
# #### Import
# #### Instantiate
# #### Fit
# #### Predict

# %%
# Import libraries to interact with html, tables, and plotting data

import pandas as pd
import numpy as np # used for linear algebra and random sampling
import seaborn as sns
from matplotlib import pyplot as plt
# used for plotting charts within the notebook (instead of a separate window)
# Allow plots to appear in the notebook.
# %matplotlib inline
import bs4
from bs4 import BeautifulSoup
from html.parser import HTMLParser
import glob
import requests
import urllib.request
from urllib.request import Request, urlopen
# !pip install requests
# !pip install requests-html
# !pip install lxml
# !pip install html5lib
# !pip install tensorflow
import requests
import lxml
import html5lib
import webbrowser
# Using Pickle to save data models in their current state so a ML model retrain is not necessary
import pickle
import joblib
import sklearn
# import tensorflow as tf
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.datasets import load_boston
from sklearn.dummy import DummyRegressor
from sklearn import model_selection
from sklearn.model_selection import cross_val_score


# print(f'TensorFlow v{tf.__version__}')
print(f'Pandas v{pd.__version__}\nNumpy v{np.__version__}')
print(f'joblib v{joblib.__version__}')
print(f'sklearn v{sklearn.__version__}')
# Out:
# Pandas: v1.3.4
# Numpy v1.21.4
# joblib v1.1.0
# sklearn v1.0.1

# %%
boston = load_boston()
data_FY2021_url = "https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters/usbp-sw-border-apprehensions"
data_FY2020_url = "https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2020"
data_FY2019_url = "https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2019"
data_FY2018_url = "https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions"
data_FY2017_url = "https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions-fy2017"

# %%
websites = [data_FY2021_url, data_FY2020_url, data_FY2019_url, data_FY2018_url, data_FY2017_url]

# %%
websites
# Out:
# ['https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters/usbp-sw-border-apprehensions',
#  'https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2020',
#  'https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2019',
#  'https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions',
#  'https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions-fy2017']

# %%
req = Request(data_FY2020_url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()

webpage[:]
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr">\n<head>\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<link rel="shortcut icon" href="https://www.cbp.gov/profiles/cbp_gov/themes/cbp_gov_theme/favicon.ico" type="image/vnd.microsoft.icon" />\n<!--[if gt IE 8]><html class="" />\n<![endif]--><!--[if IE 8]><html class="ie8" />\n<![endif]--><script type="text/javascript">dataLayer = [{"entityType":"node","entityBundle":"tab_page","entityId":"353747","entityLabel":"U.S. Border Patrol Southwest Border Apprehensions by Sector Fiscal Year 2020","entityLanguage":"en","entityTnid":"0","entityVid":"1008805","entityCreated":"1573676394","entityTaxonomy":{"tags":{"68":"Statistics","162":"Unaccompanied Children (UC)","42":"U.S. Border Patrol"}},"drupalLanguage":"en","userUid":0}];</script>\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=5.5, minimum-scale=1, user-scalable=yes" />\n<meta name="description" content="Southwest Border Unaccompanied Alien Children (0-17 yr old) Encounters1Comparisons below reflect Fiscal Year (FY) 2019 compared to FY 2020.Unaccompanied Alien Children Encounters by SectorSectorFY19 FY20 % ChangeFY19 to FY20Big Bend779526-32%Del Rio3" />\n<meta name="abstract" content="Southwest Border Unaccompanied Alien Children (0-17 yr old) Encounters1Comparisons below reflect Fiscal Year (FY) 2019 compared to FY 2020.Unaccompanied Alien Children Encounters by SectorSectorFY19 FY20 % ChangeFY19 to FY20Big Bend779526-32%Del Rio3|Updated: November 19, 2020 - 16:21" />\n<meta name="keywords" content="Statistics, Unaccompanied Children (UC), U.S. Border Patrol" />\n<link rel="canonical" href="https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2020" />\n<link rel="shortlink" href="https://www.cbp.gov/node/353747" />\n<meta property="og:site_name" content="U.S. Customs and Border Protection" />\n<meta property="og:type" content="website" />\n<meta property="og:url" content="https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2020" />\n<meta property="og:title" content="U.S. Border Patrol Southwest Border Apprehensions by Sector Fiscal Year 2020" />\n<meta property="og:image" content="https://www.cbp.gov/sites/default/files/cbp-seal-1200-630-px-2021.jpg" />\n<meta property="og:image:alt" content="U.S. Customs and Border Protection Seal" />\n<meta name="twitter:card" content="summary" />\n<meta name="twitter:site" content="@CBP" />\n<meta name="twitter:url" content="https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2020" />\n<meta name="twitter:description" content="Southwest Border Unaccompanied Alien Children (0-17 yr old) Encounters1Comparisons below reflect Fiscal Year (FY) 2019 compared to FY 2020.Unaccompanied Alien Children Encounters by SectorSectorFY19" />\n<meta name="twitter:title" content="U.S. Border Patrol Southwest Border Apprehensions by Sector Fiscal" />\n<meta name="twitter:image" content="https://www.cbp.gov/sites/default/files/cbp-seal-vertical-blue_twitter-card_600.jpg" />\n<meta name="twitter:image:alt" content="U.S. Customs and Border Protection Seal" />\n<meta name="google-site-verification" content="8a3SUUlFQoMPJy4Xs5qsC5JR60Ja2ZVlSjFtg2J0NLY" />\n  <title>U.S. Border Patrol Southwest Border Apprehensions by Sector Fiscal Year 2020 | U.S. Customs and Border Protection</title>  \n  <link type="text/css" rel="stylesheet" href="https://www.cbp.gov/sites/default/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://www.cbp.gov/sites/default/files/css/css_WBlF_kef1sqflgwtvS6Mks1AVtHnCUuKBs1iyaD7d6Y.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://www.cbp.gov/sites/default/files/css/css_CT4S7R8BFOYyo-ijEMlysU5PEyRMFTByTC3lyINXx5g.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://www.cbp.gov/sites/default/files/css/css_DBpwQ59WJpqy ...

# %%
table = pd.read_html(webpage)[:]

table
# Out:
# [  Unaccompanied Alien Children Encounters by Sector                \
#                                               Sector   FY19   FY20
#  0                                          Big Bend    779    526
#  1                                           Del Rio   3621   2199
#  2                                         El Centro   2688   1607
#  3                                           El Paso  16159   4835
#  4                                            Laredo   2521   2641
#  5                                        Rio Grande  34523  10258
#  6                                         San Diego   3335   1855
#  7                                            Tucson   5105   5949
#  8                                              Yuma   7289    687
#  9                       USBP Southwest Border Total  76020  30557
#
#
#    % ChangeFY19 to FY20
#  0                 -32%
#  1                 -39%
#  2                 -40%
#  3                 -70%
#  4                   5%
#  5                 -70%
#  6                 -44%
#  7                  17%
#  8                 -91%
#  9                 -60%  ,
#     Family Unit* Encounters by Sector Family Unit* Encounters by Sector.1  \
#  0                             Sector                                FY19
#  1                           Big Bend                               2.931
#  2                            Del Rio                               32835
#  3                          El Centro                                7873
#  4                            El Paso                              132909
#  5                             Laredo                                1169
#  6                         Rio Grande                              211631
#  7                          San Diego                               16174
#  8                             Tucson                               16199
#  9                               Yuma                               51961
#  10       USBP Southwest Border Total                              473682
#
#     Family Unit* Encounters by Sector.2 Family Unit* Encounters by Sector.3
#  0                                 FY20                % ChangeFY19 to FY20
#  1                                  382                                -87%
#  2                                 7703                                -77%
#  3                                 1057                                -87%
#  4                                10555                                -92%
#  5                                 1891                                 62%
#  6                                11666                                -94%
#  7                                 5005                                -69%
#  8                                11031                                -32%
#  9                                 2940                                -94%
#  10                               52230                                -89%  ,
#     Single Adult Encounters by Sector Single Adult Encounters by Sector.1  \
#  0                             Sector                                FY19
#  1                           Big Bend                                5927
#  2                            Del Rio                               20813
#  3                          El Centro                               24577
#  4                            El Paso                               33075
#  5                             Laredo                               34688
#  6                         Rio Grande                               92981
#  7                          San Diego                               38540
#  8                             Tucson                               42186
#  9                               Yuma                                9019
#  10       USBP Southwest Border Total                              301806
#
#     Single Adult Encounters by Sector.2 Single Adult Encounters by Sector.3
#  0                                 FY20                % ChangeFY19 to FY20
#  1                                 7720                                 30%
#  2                                30440                                 46%
#  3                                24828                                  1%
#  4                                39006                                 18%
#  5                                46893                                 35%
#  6                                68282                                -27%
#  7                                46422                                 20%
#  8                                49096                                 16%
#  9                                 5177                                -43%
#  10                              317864                                  5%  ,
#    Unaccompanied Alien Children Encounters by Country                       \
#                                               Country   FY14   FY15   FY16
#  0                                        El Salvador  16404   9389  17512
#  1                                          Guatemala  17057  13589  18913
#  2                                           Honduras  18244   5409  10468
#  3                                             Mexico  15634  11012  11926
#
#
#      FY17   FY18  FY19​   FY20
#  0   9143   4949  12021   2189
#  1  14827  22327  30329   8390
#  2   7784  10913  20398   4454
#  3   8877  10136  10487  14359  ,
#    Family Units* Encounters by Country
#                                Country   FY16   FY17   FY18    FY19   FY20
#  0                         El Salvador  27114  24122  13669   56897   4335
#  1                           Guatemala  23067  24657  50401  185233  10905
#  2                            Honduras  20226  22366  39439  188416  10485
#  3                              Mexico   3481   2271   2261    6004   9917,
#    Single Adult Encounters by Country
#                               Country    FY16    FY17    FY18    FY19    FY20
#  0                        El Salvador   27222   16495   12751   20893    9960
#  1                          Guatemala   32621   26387   42994   48606   27948
#  2                           Honduras   22258   17110   26161   44981   25152
#  3                             Mexico  175353  116790  139860  149967  228842,
#         Unnamed: 0_level_0     FMUA      UAC       SA    TOTAL
#                     Sector FY20 OCT FY20 OCT FY20 OCT FY20 OCT
#  0                Big Bend      100       33      520      653
#  1                 Del Rio     1333      219     1646     3198
#  2               El Centro       87       93     1818     1998
#  3                 El Paso     2122      329     2784     5235
#  4                  Laredo      117      216     3478     3811
#  5              Rio Grande     2854     1105     5781     9740
#  6               San Diego      333      129     3178     3640
#  7                  Tucson     2371      592     3372     6335
#  8                     Yum      404      125      264      793
#  9  Southwest Border Total     9721     2841    22840    35402,
#         Unnamed: 0_level_0     FMUA      UAC       SA    TOTAL
#                     Sector FY20 NOV FY20 NOV FY20 NOV FY20 NOV
#  0                Big Bend       64       55      407      526
#  1                 Del Rio     1215      226     1678     3119
#  2               El Centro      140      116     1655     1911
#  3                 El Paso     2293      462     2331     5086
#  4                  Laredo       90      258     3006     3354
#  5              Rio Grande     2094     1209     5254     8557
#  6               San Diego      388      170     3121     3679
#  7                  Tucson     2301      741     3472     6514
#  8                    Yuma      421       71      286      778
#  9  Southwest Border Total     9006     3308    21210    33524,
#         Unnamed: 0_level_0     FMUA      UAC         SA    TOTAL
#                     Sector FY20 DEC FY20 DEC FY20 DEC​​ FY20 DEC
#  0                Big Bend       52       46        445      543
#  1                 Del Rio      936      237       1830     3003
#  2               El Centro      121      159       1475     1755
#  3                 El Paso     2259      481       2359     5099
#  4                  Laredo       96      242       2787     3125
#  5              Rio Grande     1593     1033       5199     7825
#  6               San Diego      757      208       3132     4097
#  7                  Tucson     2416      705       3526     6647
#  8                    Yuma      365      113        281      759
#  9  Southwest Border Total     8595     3223      21035    32853,
#         Unnamed: 0_level_0     FMUA      UAC         SA    TOTAL
#                     Sector FY20 JAN FY20 JAN FY20 JAN​​ FY20 JAN
#  0                Big Bend       34       36        534      604
#  1                 Del Rio      360      135       1853     2348
#  2               El Centro      109      109       1481     1699
#  3                 El Paso     1411      425       2558     4394
#  4                  Laredo       96      290       3232     3618
#  5              Rio Grande      839      867       4773     6479
#  6               San Diego      672      173       3366     4209
#  7                  Tucson     1255      567       3335     5158
#  8                    Yuma      385       78        233      696
#  9  Southwest Border Total     5161     2680      21364    29205,
#         Unnamed: 0_level_0     FMUA      UAC         SA    TOTAL
#                     Sector FY20 FEB FY20 FEB FY20 FEB​​ FY20 FEB
#  0                Big Bend        6       52        504      562
#  1                 Del Rio      387      185       2050     2622
#  2               El Centro      262      118       1640     2020
#  3                 El Paso      476      457       2433     3366
#  4                  Laredo      107      304       3535     3946
#  5              Rio Grande      751     1027       4925     6703
#  6               San Diego     1040      183       3449     4672
#  7                  Tucson      969      666       3549     5184
#  8                    Yuma      614       77        311     1002
#  9  Southwest Border Total     4610     3070      22397    30077,
#         Unnamed: 0_level_0     FMUA      UAC         SA    TOTAL
#                     Sector FY20 MAR FY20 MAR FY20 MAR​​ FY20 MAR
#  0                Big Bend       24       32        619      675
#  1                 Del Rio      446      164       2009     2619
#  2               El Centro       76      120       1867     2063
#  3                 El Paso      522      445       2447     3414
#  4                  Laredo       63      297       3664     4024
#  5              Rio Grande      724     1109       5375     7208
#  6               San Diego      810      177       3717     4704
#  7                  Tucson      584      588       3934     5106
#  8                    Yuma      206       42        328      576
#  9  Southwest Border Total     3455     2974      23960    30389,
#         Unnamed: 0_level_0     FMUA      UAC         SA    TOTAL
#                     Sector FY20 APR FY20 APR FY20 APR​​ FY20 APR
#  0                Big Bend        3       22        482      507
#  1                 Del Rio      157       57       1813     2027
#  2               El Centro       31       43       1184     1258
#  3                 El Paso       79      112       1568     1759
#  4                  Laredo      101       73       1817     1991
#  5              Rio Grande      165      210       3084     3459
#  6               San Diego       40       46       2182     2268
#  7                  Tucson      100      148       2367     2615
#  8                    Yuma       40        1        257      298
#  9  Southwest Border Total      716      712      14754    16182,
#         Unnamed: 0_level_0     FMUA      UAC         SA    TOTAL
#                     Sector FY20 MAY FY20 MAY FY20 MAY​​ FY20 MAY
#  0                Big Bend        2       26        600      628
#  1                 Del Rio      218       91       1980     2289
#  2               El Centro       45       88       1747     1880
#  3                 El Paso      150      145       2322     2617
#  4                  Laredo      145      121       3089     3355
#  5              Rio Grande      169      192       3337     3698
#  6               San Diego       58       93       3160     3311
#  7                  Tucson      121      192       2757     3070
#  8                    Yuma       71       18        656      745
#  9  Southwest Border Total      979      966      19648    21593,
#         Unnamed: 0_level_0     FMUA      UAC         SA    TOTAL
#                     Sector FY20 JUN FY20 JUN FY20 JUN​​ FY20 JUN
#  0                Big Bend       12       35        613      660
#  1                 Del Rio      442      153       2876     3471
#  2               El Centro       23      143       2607     2773
#  3                 El Paso      186      263       3427     3876
#  4                  Laredo      177      119       3744     4040
#  5              Rio Grande      314      427       4673     5414
#  6               San Diego      229      165       4557     4951
#  7                  Tucson      125      270       4308     4703
#  8                    Yuma       73       28        847      948
#  9  Southwest Border Total     1581     1603      27652    30836,
#         Unnamed: 0_level_0     FMUA      UAC         SA    TOTAL
#                     Sector FY20 JUL FY20 JUL FY20 JUL​​ FY20 JUL
#  0                Big Bend       30       41        675      746
#  1                 Del Rio      497      196       3470     4163
#  2               El Centro       44      230       3295     3569
#  3                 El Paso      219      472       4400     5091
#  4                  Laredo      224      206       5015     5445
#  5              Rio Grande      539      692       6340     7571
#  6               San Diego      157      162       5237     5556
#  7                  Tucson      183      394       5028     5605
#  8                    Yuma       96       33        661      790
#  9  Southwest Border Total     1989     2426      34121    38536,
#         Unnamed: 0_level_0     FMUA      UAC       SA    TOTAL
#                     Sector FY20 AUG FY20 AUG FY20 AUG FY20 AUG
#  0                Big Bend       26       54     1040     1120
#  1                 Del Rio      405      245     4479     5129
#  2               El Centro       66      202     3239     3507
#  3                 El Paso      363      584     5613     6560
#  4                  Laredo      360      258     6624     7242
#  5              Rio Grande      765      930     8548    10243
#  6               San Diego      210      166     5656     6032
#  7                  Tucson      291      510     5965     6766
#  8                    Yuma      123       49      512      684
#  9  Southwest Border Total     2609     2998    41676    47283,
#         Unnamed: 0_level_0     FMUA      UAC       SA    TOTAL
#                     Sector FY20 SEP FY20 SEP FY20 SEP FY20 SEP
#  0                Big Bend       29       94     1281     1404
#  1                 Del Rio     1307      291     4756     6354
#  2               El Centro       53      186     2820     3059
#  3                 El Paso      475      661     6764     7900
#  4                  Laredo      315      257     6902     7474
#  5              Rio Grande      861     1456    10992    13309
#  6               San Diego      311      183     5669     6163
#  7                  Tucson      315      576     7482     8373
#  8                    Yuma      142       52      541      735
#  9  Southwest Border Total     3808     3756    47207    54771]

# %%
# table = soup.find_all('table')
# df = pd.read_html(str(table))

# %%
pd.read_html(webpage)[1]
# Out:
#   Family Unit* Encounters by Sector                          \
#                              Sector FY20 TD MAR FY21 TD MAR
# 0                          Big Bend         280         453
# 1                           Del Rio        4677       11148
# 2                         El Centro         795         939
# 3                           El Paso        9083        9477
# 4                            Laredo         569        1507
# 5                        Rio Grande        8853       52139
# 6                         San Diego        4000        3834
# 7                            Tucson        9896        4628
# 8                              Yuma        2395        8183
# 9       USBP Southwest Border Total       40548       92308
#
#
#   % ChangeFY20 TD MAR to FY21 TD MAR
# 0                                62%
# 1                               138%
# 2                                18%
# 3                                 4%
# 4                               165%
# 5                               489%
# 6                                -4%
# 7                               -53%
# 8                               242%
# 9                               128%

# %%
pd.read_html(webpage)[2]
# Out:
#   Single Adult Encounters by Sector                          \
#                              Sector FY20 TD MAR FY21 TD MAR
# 0                          Big Bend        3029       14091
# 1                           Del Rio       11066       53991
# 2                         El Centro        9936       21759
# 3                           El Paso       14912       53695
# 4                            Laredo       19702       50109
# 5                        Rio Grande       31308       86367
# 6                         San Diego       19961       50358
# 7                            Tucson       21189       68436
# 8                              Yuma        1703       11654
# 9       USBP Southwest Border Total      132806      410460
#
#
#   % ChangeFY20 TD MAR to FY21 TD MAR
# 0                               365%
# 1                               388%
# 2                               119%
# 3                               260%
# 4                               154%
# 5                               176%
# 6                               152%
# 7                               223%
# 8                               584%
# 9                               209%

# %%
# '''
# results = []
# def website_tables(url):
#     # Open with GET method
#     resp = requests.get(url)
#     resp_code  = resp.status_code(url)
#     # http_response 200 means OK status
#     if resp_code == 200:
#         print("Successfully opened webpage")
#         print("Here is your webpage:-\n")
        
#         for website in url:
#             # We need a parser, Python built-in HTML parser will work
#             soup = BeautifulSoup(resp.text,'html.parser')
#             results.append(str(soup))
#         else:
#             print(f"Error, your response code was {resp}")
# website_tables(websites)
# '''

# %%
# Downloading contents of the web page
url = data_FY2021_url
data = requests.get(url).text

# Creating BeautifulSoup object
soup = BeautifulSoup(data, 'html.parser')

# Verifying tables and their classes
print('Classes of each table:')
for table in soup.find_all('table'):
    print(table.get('class'))
# Out:
# Classes of each table:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
resp = requests.get("https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters/usbp-sw-border-apprehensions")

soup = BeautifulSoup(resp.text,'html.parser')
print(resp)
print(soup)
soup.body
# resp_code  = resp.status_code(data_FY2021_url)
# Out:
# <Response [200]>
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="https://www.cbp.gov/profiles/cbp_gov/themes/cbp_gov_theme/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <!--[if gt IE 8]><html class="" />
# <![endif]--><!--[if IE 8]><html class="ie8" />
# <![endif]--><script type="text/javascript">dataLayer = [{"entityType":"node","entityBundle":"accordion_page","entityId":"365977","entityLabel":"U.S. Border Patrol Southwest Border Apprehensions by Sector","entityLanguage":"en","entityTnid":"0","entityVid":"1086246","entityCreated":"1605038683","entityTaxonomy":{"tags":{"68":"Statistics","162":"Unaccompanied Children (UC)","42":"U.S. Border Patrol"}},"drupalLanguage":"en","userUid":0}];</script>
# <meta content="width=device-width, initial-scale=1, maximum-scale=5.5, minimum-scale=1, user-scalable=yes" name="viewport"/>
# <meta content="NOTE: This webpage is no longer updated." name="description"/>
# <meta content="NOTE: This webpage is no longer updated.|Updated: June 10, 2021 - 06:41" name="abstract"/>
# <meta content="Statistics, Unaccompanied Children (UC), U.S. Border Patrol" name="keywords"/>
# <link href="https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters/usbp-sw-border-apprehensions" rel="canonical"/>
# <link href="https://www.cbp.gov/node/365977" rel="shortlink"/>
# <meta content="U.S. Customs and Border Protection" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters/usbp-sw-border-apprehensions" property="og:url"/>
# <meta content="U.S. Border Patrol Southwest Border Apprehensions by Sector" property="og:title"/>
# <meta content="https://www.cbp.gov/sites/default/files/cbp-seal-1200-630-px-2021.jpg" property="og:image"/>
# <meta content="U.S. Customs and Border Protection Seal" property="og:image:alt"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@CBP" name="twitter:site"/>
# <meta content="https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters/usbp-sw-border-apprehensions" name="twitter:url"/>
# <meta content="NOTE: This webpage is no longer updated." name="twitter:description"/>
# <meta content="U.S. Border Patrol Southwest Border Apprehensions by Sector" name="twitter:title"/>
# <meta content="https://www.cbp.gov/sites/default/files/cbp-seal-vertical-blue_twitter-card_600.jpg" name="twitter:image"/>
# <meta content="U.S. Customs and Border Protection Seal" name="twitter:image:alt"/>
# <meta content="8a3SUUlFQoMPJy4Xs5qsC5JR60Ja2ZVlSjFtg2J0NLY" name="google-site-verification"/>
# <title>U.S. Border Patrol Southwest Border Apprehensions by Sector | U.S. Customs and Border Protection</title>
# <link href="https://www.cbp.gov/sites/default/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.cbp.gov/sites/default/files/css/css_WBlF_kef1sqflgwtvS6Mks1AVtHnCUuKBs1iyaD7d6Y.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.cbp.gov/sites/default/files/css/css_CT4S7R8BFOYyo-ijEMlysU5PEyRMFTByTC3lyINXx5g.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.cbp.gov/sites/default/files/css/css_DBpwQ59WJpqy8G61T9YeYc7RAKi20mlfq6kd9n6T_Ak.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.cbp.gov/sites/default/files/css/css_TJaz4NNK5iRA2Xv4fEu7lkBB6ICF-AbddeM6RLuevao.css" media="all" rel="stylesheet" type="text/css"/>
# <!--[if (lt IE 9)&(!IEMobile)]>
# <link type="text/css" rel="stylesheet" href="https://www.cbp.gov/sites/default/files/css/css_Iqst9_HSYVlwhTSx1BgIEtE_v9FYuzb-rVKMeNt5vQ4.css" media="all" />
# <![endif]-->
# <!--[if gte IE 9]><!-->
# <link href="https://www.cbp.gov/sites/default/files/css/css_oUTOafIqM4HCjk9-02ghpYZPs6NO5bADjMz_N6L5QvM.css" media="all" rel="stylesheet" type="text/css"/>
# <!--<![endif]-->
# <script src="https://www.cbp.gov/sites/default/files/js/js_H12TIeZuDZ58onuwBY-2MmZkywp54u18ddOAqapREgw.js" type="text/javascript"></script>
# <script src="https://www.cbp.gov/sites/default/files/js/js_CAYfRHtJsEgO-R0EbhemqT7-A9QUI7-f9R33ltBsCoY.js" type="text/javascript"></script>
# <script src="https://www.cbp.gov/sites/all/libraries/mediaelement/build/mediaelement-and-player.min.js?v=4" type="text/javascript"></script>
# <script src="https://www.cbp.gov/sites/default/files/js/js_THmHRj8l5I-1sVjAVGaLCeWVMspfQ0is9nyAdE7wV2I.js" type="text/javascript"></script>
# <script src="https://www.cbp.gov/sites/default/files/js/js_ZfGaDniqhRRwJazjl0vrSm3SB8aJ5Y8SSFGemaH3_Ho.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
#
#     jQuery(document).ready(function($){
#       $('#om-maximenu-main-navigation li.om-leaf .om-maximenu-content').removeClass('om-maximenu-content-nofade');
#       $('#om-maximenu-main-navigation li.om-leaf .om-link').click(function(ev) {
#         ev.stopPropagation();
#         if($(this).parent().hasClass('open')) {
#           $(this).parent().removeClass('open');
#         }
#         else {
#           $('#om-maximenu-main-navigation li.om-leaf').removeClass('open');
#           $(this).parent().addClass('open');
#         }
#
#         $(this).parent().siblings().children('.om-maximenu-content').slideUp('slow');
#         $(this).siblings('.om-maximenu-content').toggle('slow').pause();
#         return false;
#       });
#       $('#om-maximenu-main-navigation .om-maximenu-content').click(function(ev) {
#         ev.stopPropagation();
#       });
#       $('html').click(function() {
#         // Close any open menus.
#         $('#om-maximenu-main-navigation .om-maximenu-content:visible').each(function() {
#           $(this).parent().removeClass('open');
#           $(this).hide();
#         });
#       });
#     });
#
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# window.CKEDITOR_BASEPATH = '/sites/all/libraries/ckeditor/'
# //--><!]]>
# </script>
# <script src="https://www.cbp.gov/sites/default/files/js/js_TCaU6MrAT-pFP6DXqwcxWXKgtMGAiU07CBjoQ7Po53Q.js" type="text/javascript"></script>
# <script src="https://www.cbp.gov/sites/default/files/js/js_8hA20aMyCzL6qLzEPwScWwHg7NfU5nbdw7I1CJEfjR0.js" type="text/javascript"></script>
# <script src="https://www.cbp.gov/sites/default/files/js/js_43n5FBy8pZxQHxPXkf-sQF7ZiacVZke14b0VlvSA554.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"cbp_gov_theme","theme_token":"XCwM8YMoOEVruuEW9jNaK2EqsHe7hzy9-IsQrAqUlnE","js":{"profiles\/cbp_gov\/modules\/contrib\/extlink_extra\/extlink_extra.js":1,"0":1,"public:\/\/google_tag\/google_tag.script.js":1,"sites\/all\/modules\/jquery_update\/replace\/jquery\/1.10\/jquery.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"sites\/all\/libraries\/mediaelement\/build\/mediaelement-and-player.min.js":1,"profiles\/cbp_gov\/modules\/custom\/fancy_file_delete\/js\/fancyfiledelete.js":1,"profiles\/cbp_gov\/modules\/contrib\/om_maximenu\/js\/om_maximenu.js":1,"sites\/all\/libraries\/bootstrap\/js\/bootstrap.min.js":1,"sites\/all\/libraries\/colorbox\/jquery.colorbox-min.js":1,"sites\/all\/modules\/colorbox\/js\/colorbox.js":1,"sites\/all\/modules\/colorbox\/styles\/default\/colorbox_style.js":1,"sites\/all\/modules\/colorbox\/js\/colorbox_inline.js":1,"profiles\/dhs_wcm\/modules\/contrib\/mediaelement\/mediaelement.js":1,"sites\/all\/modules\/custom\/wcm_survey\/js\/wcm_survey.js":1,"sites\/all\/modules\/custom\/wcm_survey\/js\/json3.min.js":1,"sites\/all\/modules\/custom\/wcm_survey\/js\/jquery.cookie.js":1,"1":1,"2":1,"profiles\/cbp_gov\/themes\/cbp_gov_theme\/js\/cbp_gov_accordion.js":1,"sites\/all\/modules\/extlink\/js\/extlink.js":1,"profiles\/cbp_gov\/modules\/custom\/cbp_social_links\/js\/cbp_social_links.js":1,"profiles\/cbp_gov\/modules\/contrib\/datalayer\/datalayer.js":1,"profiles\/cbp_gov\/modules\/custom\/custom_cbp_gov\/js\/cbp.js":1,"profiles\/cbp_gov\/themes\/cbp_gov_theme\/js\/jquery.hoverIntent.minified.js":1,"profiles\/cbp_gov\/themes\/cbp_gov_theme\/js\/cbp_gov.hoverIntent.js":1,"profiles\/cbp_gov\/themes\/cbp_gov_theme\/js\/cbp_gov.frontline_magazine.js":1,"profiles\/cbp_gov\/themes\/cbp_gov_theme\/js\/cbp_gov.GlobalStylesOff.js":1,"profiles\/cbp_gov\/themes\/cbp_gov_theme\/js\/cbp_gov_508_fixes.js":1,"profiles\/cbp_gov\/themes\/cbp_gov_theme\/js\/cbp_gov.site_wide_fixes.js":1,"profiles\/cbp_gov\/themes\/cbp_gov_theme\/js\/cbp_gov.search_gov.js":1,"profiles\/cbp_gov\/themes\/cbp_gov_theme\/js\/recruiting_form.js":1,"profiles\/cbp_gov\/themes\/omega\/omega\/js\/jquery.formalize.js":1,"profiles\/cbp_gov\/themes\/omega\/omega\/js\/omega-mediaqueries.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"sites\/all\/libraries\/mediaelement\/build\/mediaelementplayer.min.css":1,"modules\/aggregator\/aggregator.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"profiles\/cbp_gov\/modules\/contrib\/office_hours\/office_hours.css":1,"profiles\/cbp_gov\/modules\/contrib\/om_maximenu\/css\/om_maximenu.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/custom\/wcm_survey\/wcm_survey.css":1,"sites\/all\/modules\/extlink\/css\/extlink.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/media\/modules\/media_wysiwyg\/css\/media_wysiwyg.base.css":1,"sites\/all\/libraries\/bootstrap\/css\/bootstrap.min.css":1,"sites\/all\/libraries\/bootstrap\/css\/bootstrap-theme.min.css":1,"sites\/all\/modules\/colorbox\/styles\/default\/colorbox_style.css":1,"profiles\/dhs_wcm\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/custom\/wcm_node_feedback\/wcm_node_feedback.css":1,"profiles\/cbp_gov\/modules\/contrib\/print\/print_ui\/css\/print_ui.theme.css":1,"profiles\/cbp_gov\/modules\/contrib\/om_maximenu\/skin\/no_style\/no_style.css":1,"profiles\/cbp_gov\/modules\/contrib\/extlink_extra\/extlink_extra.508.css":1,"sites\/all\/modules\/field_collection\/field_collection.theme.css":1,"profiles\/cbp_gov\/modules\/custom\/cbp_social_links\/css\/cbp_social_links.css":1,"profiles\/ ...
# //--><!]]>
# </script>
# <!-- We participate in the US government's analytics program. See the data at analytics.usa.gov. --><script id="_fed_an_ua_tag" src="/profiles/dhs_wcm/modules/contrib/usfedgov_google_analytics/js/Universal-Federated-Analytics-Min.js?agency=DHS&amp;subagency=CBP" type="text/javascript"></script> <!--[if lt IE 9]><script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script><![endif]-->
# </head>
# <body class="html not-front not-logged-in page-node page-node- page-node-365977 node-type-accordion-page context-newsroom">
# <div id="skip-link">
# <a class="element-invisible element-focusable" href="#main-content">Skip to main content</a>
# </div>
# <div class="region region-page-top" id="region-page-top">
# <div class="region-inner region-page-top-inner">
# <noscript aria-hidden="true"><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5Q9H8F" style="display:none;visibility:hidden" width="0"></iframe></noscript> </div>
# </div> <div class="page clearfix" id="page">
# <header class="section section-header" id="section-header">
# <div class="zone-wrapper zone-user-wrapper clearfix" id="zone-user-wrapper">
# <div class="zone zone-user clearfix container-12" id="zone-user">
# <div class="grid-12 region region-user-second" id="region-user-second">
# <div class="region-inner region-user-second-inner">
# <div class="block block-boxes block-boxes-simple block-official-website-claim block-boxes-official-website-claim odd block-without-title" id="block-boxes-official-website-claim">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <div class="boxes-box" id="boxes-box-official_website_claim"><div class="boxes-box-content"><p class="pull-left"><img alt="US flag" src="https://www.dhs.gov/sites/default/files/images/icn-us-flag-21px.png" style="width: 21px; height: 13px; "/> Official website of the Department of Homeland Security</p></div></div> </div>
# </div>
# </div><div class="block block-menu block-menu-utility block-menu-menu-utility even block-without-title" id="block-menu-menu-utility">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <ul class="menu"><li class="first leaf"><a href="https://public.govdelivery.com/accounts/USDHSCBP/subscriber/new " title="Get Email Updates">Get Email Updates</a></li>
# <li class="leaf"><a href="/contact" title="">Contact Us</a></li>
# <li class="leaf"><a href="https://helpspanish.cbp.gov/s/?language=es" hreflang="es" lang="es" title="CBP spanish language knowledgebase">Comunicarse con Nosotros</a></li>
# <li class="last leaf"><a href="/employee-resources" title="">Employee and Family Resources</a></li>
# </ul> </div>
# </div>
# </div><div class="block block-boxes block-boxes-simple block-footer-social-media block-boxes-footer-social-media odd block-without-title" id="block-boxes-footer-social-media">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <div class="boxes-box" id="boxes-box-footer_social_media"><div class="boxes-box-content"><ul class="social-buttons"><li class="social-button"><a href="https://www.facebook.com/CBPgov/" target="_new"><img alt="Facebook" src="/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_facebook-508.png" style="width: 27px; height: 27px; margin-right: 10px; margin-bottom: 5px;"/></a></li><li class="social-button"><a href="https://www.instagram.com/cbpgov/" target="_new"><img alt="Instagram" src="/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_instagram-508.png" style="width: 27px; height: 27px; margin-right: 10px; margin-bottom: 5px;"/></a></li><li class="social-button"><a href="https://www.flickr.com/photos/cbpphotos/" target="_new"><img alt="Flickr" src="/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_flickr-508.png" style="width: 27px; height: 27px; margin-right: 10px; margin-bottom: 5px;"/></a></li><li class="social-button"><a href="https://twitter.com/cbp" target="_new"><img alt="Twitter" src="/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_twitter-508.png" style="width: 27px; height: 27px; margin-right: 10px; margin-bottom: 5px;"/></a></li><li class="social-button"><a href="https://www.linkedin.com/company/2997?trk=tyah" target="_new"><img alt="Linkedin" src="/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_linkedin-508.png" style="width: 27px; height: 27px; margin-right: 10px; margin-bottom: 5px;"/></a></li><li class="social-button"><a href="https://www.youtube.com/user/customsborderprotect" target="_new"><img alt="YouTube" src="/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_youtube-508.png" style="width: 27px; height: 27px; margin-right: 10px; margin-bottom: 5px;"/></a></li><li class="social-button"><a href="https://public.govdelivery.com/accounts/USDHSCBP/subscriber/new" target="_new"><img alt="Mail Us" src="/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_mail-508.png" style="width: 27px; height: 27px; margin-right: 10px; margin-bottom: 5px;"/></a></li></ul></div></div> </div>
# </div>
# </div><div class="block block-search block-form block-search-form even block-without-title" id="block-search-form">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <form accept-charset="UTF-8" action="https://search.usa.gov/search" id="search-block-form" method="get"><div><div class="container-inline">
# <!--<h2 class="element-invisible"></h2> -->
# <div class="form-item form-type-textfield form-item-search-block-form">
# <label class="element-invisible" for="edit-search-block-form--2">Search </label>
# <input autocomplete="off" class="usagov-search-autocomplete ui-autocomplete-input ui-corner-all form-text" id="edit-search-block-form--2" maxlength="128" name="query" size="15" type="text" value=""/>
# </div>
# <div class="form-actions form-wrapper" id="edit-actions"><input class="form-submit" id="edit-submit" name="op" type="submit" value="Search"/></div><input name="affiliate" type="hidden" value="cbpgov"/>
# </div>
# </div></form> </div>
# </div>
# </div> </div>
# </div> </div>
# </div><div class="zone-wrapper zone-branding-wrapper clearfix" id="zone-branding-wrapper">
# <div class="zone zone-branding clearfix container-12" id="zone-branding">
# <div class="grid-12 region region-branding" id="region-branding">
# <div class="region-inner region-branding-inner">
# <div class="block block-delta-blocks block-logo block-delta-blocks-logo odd block-without-title" id="block-delta-blocks-logo">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <div class="logo-img"><a href="/" id="logo" title="Return to the US Department of Homeland Security Logo home page"><img alt="US Department of Homeland Security Logo" src="https://www.cbp.gov/profiles/cbp_gov/themes/cbp_gov_theme/logo_2.png"/></a></div> </div>
# </div>
# </div><div class="block block-delta-blocks block-site-name block-delta-blocks-site-name even block-without-title" id="block-delta-blocks-site-name">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <h2 class="site-name"><a href="/" title="Return to the U.S. Customs and Border Protection home page"><span>U.S. Customs and Border Protection</span></a></h2> </div>
# </div>
# </div><div class="block block-boxes block-boxes-simple block-mobile-nav-button block-boxes-mobile-nav-button odd block-without-title" id="block-boxes-mobile-nav-button">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <div class="boxes-box" id="boxes-box-mobile_nav_button"><div class="boxes-box-content"><p class="mobile_nav_button" style="width: 38px; height: 29px;"> </p></div></div> </div>
# </div>
# </div> </div>
# </div> </div>
# </div><div class="zone-wrapper zone-menu-wrapper clearfix" id="zone-menu-wrapper">
# <div class="zone zone-menu clearfix container-12" id="zone-menu">
# <div class="grid-12 region region-menu" id="region-menu">
# <div class="region-inner region-menu-inner">
# <div class="block block-om-maximenu block-om-maximenu-1 block-om-maximenu-om-maximenu-1 odd block-without-title" id="block-om-maximenu-om-maximenu-1">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <div class="om-maximenu om-maximenu-no-style om-maximenu-block om-maximenu-row om-maximenu-block-down code-om-u1-1651491828" id="om-maximenu-main-navigation">
# <div class="om-menu-ul-wrapper" id="om-menu-main-navigation-ul-wrapper">
# <ul class="om-menu" id="om-menu-main-navigation">
# <li class="om-leaf first leaf-about-cbp" id="om-leaf-om-u1-1651491828-1">
# <a class="om-link link-about-cbp" href="/about">About CBP</a>
# <div class="om-maximenu-content om-maximenu-content-nofade closed">
# <div class="om-maximenu-top">
# <div class="om-maximenu-top-left"></div>
# <div class="om-maximenu-top-right"></div>
# </div><!-- /.om-maximenu-top -->
# <div class="om-maximenu-middle">
# <div class="om-maximenu-middle-left">
# <div class="om-maximenu-middle-right">
# <div class="block block-views block-views-id-menu_featured_item-block_18 first">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_18 view-dom-id-584e2d3402f15c608e2db5daf7a37714">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/about "><img alt="Photo of the operational components of CBP" height="148" src="https://www.cbp.gov/sites/default/files/photo/2020vision-210x148.jpg" title="Photo of the operational components of CBP" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Who We Are</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-views block-views-id-menu_featured_item-block">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block view-dom-id-4c5fa4ddafb788d5b38f0899a7a1b03b">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/about "><img alt="CBP Officer Arm Patch" height="148" src="https://www.cbp.gov/sites/default/files/About%20CBP.jpg" title="CBP Officer Arm Patch" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Learn About CBP</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_about_cbp">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_about_cbp"><div class="boxes-box-content"><p><a href="/about/leadership-organization">Leadership/Organization</a></p><p><a href="/about/history">History</a></p><p><a href="/about/in-memoriam">In Memoriam</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="block block-views block-views-id-menu_featured_item-block_16">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_16 view-dom-id-83d70f14bf5f6deacd32286ee69be2fd">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/about/environmental-cultural-stewardship "><img alt="US Customs House" height="148" src="https://www.cbp.gov/sites/default/files/photo/MaxiMenu-About-CBP-uscustomshouse-210x148.jpg" title="US Customs House" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Environmental Stewardship</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_about_cbp_feature_2">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_about_cbp_feature_2"><div class="boxes-box-content"><p><a href="/about/environmental-mangement-sustainability/cbp-environmental-documents" title="Document Review/Comment">Document Review/Comment</a></p><p><a href="/about/environmental-mangement-sustainability/nepa" title="NEPA">NEPA</a></p><p><a href="/about/environmental-mangement-sustainability/preserving-cultural-resources" title="Preserving Cultural Resources">Preserving Cultural Resources</a></p><p><a href="/about/environmental-mangement-sustainability/sustainability-resilience" title="Sustainability">Sustainability</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="block block-views block-views-id-menu_featured_item-block_17">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_17 view-dom-id-8ea219d20ed135144cf8e86e45d96c5d">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/about/congressional-resources "><img alt="US Capitol building" height="148" src="https://www.cbp.gov/sites/default/files/photo/MaxiMenu-About-CBP-CapitolCrop-210x148.jpg" title="US Capitol building" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Congressional Resources</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_about_cbp_feature_3">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_about_cbp_feature_3"><div class="boxes-box-content"><p><a href="/about/congressional-resources/congressional-staff-resources">Congressional Staff Resources</a></p><p><a href="/about/congressional-resources/protocol-congressional-facility-visits">Congressional Delegations</a></p><p><a href="/about/congressional-resources/faqs" title="Congressional Office FAQs">Congressional Office FAQs</a></p><p><a href="/about/congressional-resources/news-events/CBP-access" title="CBP Access">CBP Access</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_about_cbp_feature_4 last">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_about_cbp_feature_4"><div class="boxes-box-content"><p><a href="/cbp-snapshot">CBP Snapshot of Operations</a></p><p><a href="/newsroom/stats/typical-day-fy2020" title="A Typical Day at CBP">A Typical Day at CBP</a></p><p><a href="/document/publications/u-s-customs-and-border-protection-strategy-2020-2025" target="_blank" title="Vision and Strategy 2020">Vision and Strategy 2025</a></p><p><a href="/newsroom/publications/performance-accountability-financial" title="Performance, Accountability and Financial Reports">Performance, Accountability and Financial Reports</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="om-clearfix"></div>
# </div><!-- /.om-maximenu-middle-right -->
# </div><!-- /.om-maximenu-middle-left -->
# </div><!-- /.om-maximenu-middle -->
# <div class="om-maximenu-bottom">
# <div class="om-maximenu-bottom-left"></div>
# <div class="om-maximenu-bottom-right"></div>
# </div><!-- /.om-maximenu-bottom -->
# <div class="om-maximenu-arrow"></div>
# <div class="om-maximenu-open"></div>
# <!-- /.om-maximenu-open -->
# </div><!-- /.om-maximenu-content -->
# </li>
# <li class="om-leaf leaf-newsroom" id="om-leaf-om-u1-1651491828-2">
# <a class="om-link link-newsroom" href="/newsroom">Newsroom</a>
# <div class="om-maximenu-content om-maximenu-content-nofade closed">
# <div class="om-maximenu-top">
# <div class="om-maximenu-top-left"></div>
# <div class="om-maximenu-top-right"></div>
# </div><!-- /.om-maximenu-top -->
# <div class="om-maximenu-middle">
# <div class="om-maximenu-middle-left">
# <div class="om-maximenu-middle-right">
# <div class="block block-views block-views-id-menu_featured_item-block_12 first">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_12 view-dom-id-7749881041fe0e040600104c6be5f867">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/newsroom "><img alt="CBP, CBSA Host Joint Media Event" height="148" src="https://www.cbp.gov/sites/default/files/assets/featured-images/2017-Jan/maximenu-newsroom-media-20170118-210x148.jpg" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Media &amp; Public</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_newsroom_media_public">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_newsroom_media_public"><div class="boxes-box-content"><p><a href="/newsroom/press">Press Officers</a></p><p><a href="/newsroom/media-releases/all" title="Media Releases">Media Releases</a></p><p><a href="/newsroom/news/advisories" title="Advisories">Advisories</a></p><p><a href="/newsroom/speeches" title="Speeches/Statements">Speeches/Statements</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="block block-views block-views-id-menu_featured_item-block_13">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_13 view-dom-id-17f0d93c18cdd53cc3c7e06bd0d93874">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/newsroom/photo-gallery "><img alt="Helicopter with Aerostat in background" height="148" src="https://www.cbp.gov/sites/default/files/photo/Menu-Newsroom-Imagery-210x148.jpg" title="Helicopter with Aerostat in background" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Imagery</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_newsroom_imagery">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_newsroom_imagery"><div class="boxes-box-content"><p><a href="/newsroom/photo-gallery" title="Photo Gallery">Photo Gallery</a></p><p><a href="/newsroom/video-gallery" title="Video Gallery">Video Gallery</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="block block-views block-views-id-menu_featured_item-block_14">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_14 view-dom-id-236719a76884997676f974ca434fd7cd">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/newsroom "><img alt="Agents escorting illegal aliens" height="148" src="https://www.cbp.gov/sites/default/files/photo/Menu-Newsroom-Background-210x148.jpg" title="Agents escorting illegal aliens" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Background</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_newsroom_background">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_newsroom_background"><div class="boxes-box-content"><p><a href="/newsroom/stats" title="Stats and Summaries">Stats and Summaries</a></p><p><a href="/newsroom/fact-sheets" title="Fact Sheets">Fact Sheets</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="block block-views block-views-id-menu_featured_item-block_15">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_15 view-dom-id-8301af4921c92bc9db79e3b7e9a07d48">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/frontline "><img alt="Frontline - Official Digital Publication of U.S. Customs and Border Protection" height="148" src="https://www.cbp.gov/sites/default/files/photo/frontline-menu-cbp-1.jpg" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Publications</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_newsroom_publications last">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_newsroom_publications"><div class="boxes-box-content"><p><a href="/frontline" title="Frontline Digital">Frontline Digital</a></p><p><a href="/newsroom/publications/performance-accountability-financial" title="Reports">Reports</a></p><p><a href="/newsroom/publications/forms" title="Forms">Forms</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="om-clearfix"></div>
# </div><!-- /.om-maximenu-middle-right -->
# </div><!-- /.om-maximenu-middle-left -->
# </div><!-- /.om-maximenu-middle -->
# <div class="om-maximenu-bottom">
# <div class="om-maximenu-bottom-left"></div>
# <div class="om-maximenu-bottom-right"></div>
# </div><!-- /.om-maximenu-bottom -->
# <div class="om-maximenu-arrow"></div>
# <div class="om-maximenu-open"></div>
# <!-- /.om-maximenu-open -->
# </div><!-- /.om-maximenu-content -->
# </li>
# <li class="om-leaf leaf-travel" id="om-leaf-om-u1-1651491828-3">
# <a class="om-link link-travel" href="/travel">Travel</a>
# <div class="om-maximenu-content om-maximenu-content-nofade closed">
# <div class="om-maximenu-top">
# <div class="om-maximenu-top-left"></div>
# <div class="om-maximenu-top-right"></div>
# </div><!-- /.om-maximenu-top -->
# <div class="om-maximenu-middle">
# <div class="om-maximenu-middle-left">
# <div class="om-maximenu-middle-right">
# <div class="block block-views block-views-id-menu_featured_item-block_5 first">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_5 view-dom-id-af4171f1a848b60afebc7b1c74940812">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/travel/us-citizens "><img alt="A CBP Officer inspects a vehicle and passengers at a land border port of entry" height="140" src="https://www.cbp.gov/sites/default/files/photo/Land%20Border%20POE_0.jpg" title="A CBP Officer inspects a vehicle and passengers at a land border port of entry" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">U.S. Citizens/LPRs</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_travel_citizen_lpr">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_travel_citizen_lpr"><div class="boxes-box-content"><ul><li><a href="/travel/us-citizens/apc">Automated Passport Control</a></li><li><a href="/travel/us-citizens/mobile-passport-control">Mobile Passport Control</a></li><li><a href="/travel/us-citizens/canada-mexico-travel">Canada and Mexico Travel</a></li><li><a href="/travel/us-citizens/know-before-you-go">Know Before You Go</a></li></ul></div></div></div>
# </div><!-- /.block -->
# <div class="block block-views block-views-id-menu_featured_item-block_7">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_7 view-dom-id-634fe068ed337ab2c09927d99152e279">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/travel/international-visitors "><img alt="CBP Officer Inspecting Luggage" height="148" src="https://www.cbp.gov/sites/default/files/International%20Visitors.jpg" title="CBP Officer Inspecting Luggage" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">International Visitors</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_travel_visitors">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_travel_visitors"><div class="boxes-box-content"><ul><li><a href="/travel/international-visitors/esta">ESTA</a></li><li><a href="/travel/international-visitors/visa-waiver-program">Visa Waiver Program</a></li><li><a href="/travel/international-visitors/know-before-you-go">Know Before You Visit</a></li></ul></div></div></div>
# </div><!-- /.block -->
# <div class="block block-views block-views-id-menu_featured_item-block_6">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_6 view-dom-id-929471b72d8d9bd427bc8a3109be7a24">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/travel/trusted-traveler-programs "><img alt="Traveler Checking In" height="148" src="https://www.cbp.gov/sites/default/files/Trusted%20Traveler%20Programs.jpg" title="Traveler Checking In" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Trusted Traveler Programs</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_travel_trusted last">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_travel_trusted"><div class="boxes-box-content"><ul><li><a href="/travel/trusted-traveler-programs/global-entry">Global Entry</a></li><li><a href="/travel/trusted-traveler-programs/nexus">NEXUS</a></li><li><a href="/travel/trusted-traveler-programs/sentri">SENTRI</a></li><li><a href="/travel/trusted-traveler-programs/fast">FAST</a></li></ul></div></div></div>
# </div><!-- /.block -->
# <div class="om-clearfix"></div>
# </div><!-- /.om-maximenu-middle-right -->
# </div><!-- /.om-maximenu-middle-left -->
# </div><!-- /.om-maximenu-middle -->
# <div class="om-maximenu-bottom">
# <div class="om-maximenu-bottom-left"></div>
# <div class="om-maximenu-bottom-right"></div>
# </div><!-- /.om-maximenu-bottom -->
# <div class="om-maximenu-arrow"></div>
# <div class="om-maximenu-open"></div>
# <!-- /.om-maximenu-open -->
# </div><!-- /.om-maximenu-content -->
# </li>
# <li class="om-leaf leaf-trade" id="om-leaf-om-u1-1651491828-4">
# <a class="om-link link-trade" href="/trade">Trade</a>
# <div class="om-maximenu-content om-maximenu-content-nofade closed">
# <div class="om-maximenu-top">
# <div class="om-maximenu-top-left"></div>
# <div class="om-maximenu-top-right"></div>
# </div><!-- /.om-maximenu-top -->
# <div class="om-maximenu-middle">
# <div class="om-maximenu-middle-left">
# <div class="om-maximenu-middle-right">
# <div class="block block-views block-views-id-menu_featured_item-block_8 first">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_8 view-dom-id-617e448e2eec1dacf3885d9bc52c1765">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/trade/basic-import-export "><img alt="Photo of Mini Cooper that was illegally imported" height="148" src="https://www.cbp.gov/sites/default/files/photo/ot-minicooper-20150205.jpg" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Basic Import and Export</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_trade_import_export">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_trade_import_export"><div class="boxes-box-content"><p><a href="/trade/basic-import-export/importing-car" title="Importing a Car">Importing a Car</a></p><p><a href="/trade/basic-import-export/export-docs/motor-vehicle" title="Exporting a Car">Exporting a Car</a></p><p><a href="/trade/basic-import-export/importer-exporter-tips" title="Importer/Exporter Tips">Importer/Exporter Tips</a></p><p><a href="/trade/basic-import-export/internet-purchases" title="Internet Purchases">Internet Purchases</a></p><p><a href="/trade/priority-issues/trade-agreements/free-trade-agreements/USMCA">USMCA</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="block block-views block-views-id-menu_featured_item-block_10">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_10 view-dom-id-f12d33cda4a2a5e21588b3768f5d175e">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/trade/automated "><img alt="U.S. Single Window for Trade" height="148" src="https://www.cbp.gov/sites/default/files/photo/ot-singlewindow-20150205.jpg" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Automation/Agency Partners</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_trade_automated_systems">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_trade_automated_systems"><div class="boxes-box-content"><p><a href="/trade/automated/getting-started" title="Getting Started with ACE">Getting Started with ACE</a></p><p><a href="/ace-pga" title="PGA Integration">PGA Integration</a></p><p><a href="/trade/ace/whats-new-innovation">Innovation</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="block block-views block-views-id-menu_featured_item-block_9">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_9 view-dom-id-3f3642b9a66e89d9f90609dcbd0976a3">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/trade/priority-issues/import-safety "><img alt="Counterfeit NFL Apparel" height="148" src="https://www.cbp.gov/sites/default/files/photo/ot-counterfeitapparel-20150205.jpg" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Key Trade Issues</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_trade_resources">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_trade_resources"><div class="boxes-box-content"><p><a href="/trade/stakeholder-engagement" title="Stakeholder Outreach">Stakeholder Outreach</a></p><p><a href="/trade/priority-issues" title="Priority Trade Issues">Priority Trade Issues</a></p><p><a href="/trade/programs-administration/customs-brokers" title="Brokers">Brokers</a></p><p><a href="/trade/quota" title="Quota">Quota</a></p><p><a href="/trade/programs-administration/forced-labor" title="AD/CVD">Forced Labor</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="block block-views block-views-id-menu_featured_item-block_11">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_11 view-dom-id-006e0cdf9807420b133957823cbd7871">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/trade/rulings "><img alt="Federal Register Notice" height="148" src="https://www.cbp.gov/sites/default/files/photo/ot-frn-20150205.png" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Rulings &amp; Legal Decisions</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_trade_outreach last">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_trade_outreach"><div class="boxes-box-content"><p><a href="/trade/rulings/eruling-requirements" title="eRuling Requirements">eRuling Requirements</a></p><p><a href="/trade/rulings/trade-related-federal-register-notices" title="Federal Register Notices">Federal Register Notices</a></p><p><a href="/trade/rulings/bulletin-decisions" title="Customs Bulletin and Decisions">Customs Bulletin and Decisions</a></p><p><a href="/trade/rulings/informed-compliance-publications" title="Informed Compliance Publications">Informed Compliance Publications</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="om-clearfix"></div>
# </div><!-- /.om-maximenu-middle-right -->
# </div><!-- /.om-maximenu-middle-left -->
# </div><!-- /.om-maximenu-middle -->
# <div class="om-maximenu-bottom">
# <div class="om-maximenu-bottom-left"></div>
# <div class="om-maximenu-bottom-right"></div>
# </div><!-- /.om-maximenu-bottom -->
# <div class="om-maximenu-arrow"></div>
# <div class="om-maximenu-open"></div>
# <!-- /.om-maximenu-open -->
# </div><!-- /.om-maximenu-content -->
# </li>
# <li class="om-leaf leaf-border-security" id="om-leaf-om-u1-1651491828-5">
# <a class="om-link link-border-security" href="/border-security">Border Security</a>
# <div class="om-maximenu-content om-maximenu-content-nofade closed">
# <div class="om-maximenu-top">
# <div class="om-maximenu-top-left"></div>
# <div class="om-maximenu-top-right"></div>
# </div><!-- /.om-maximenu-top -->
# <div class="om-maximenu-middle">
# <div class="om-maximenu-middle-left">
# <div class="om-maximenu-middle-right">
# <div class="block block-views block-views-id-menu_featured_item-block_1 first">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_1 view-dom-id-9fe6082e3b0d0e839b64e74fdfd764e5">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-caption"> <div class="field-content"></div> </div>
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="https://www.cbp.gov/border-security/along-us-borders "><img alt="Photo of Border Patrol Agent looking through Binoculars" height="148" src="https://www.cbp.gov/sites/default/files/photo/bp-maximenu-210x148.jpg" title="Along US Borders" width="210"/></a></div> </div>
# <div class="views-field views-field-field-description"> <div class="field-content"><p class="manual-fix" style="width: 13.1em;">Along US Borders</p></div> </div> </div>
# </div>
# </div></div>
# </div><!-- /.block -->
# <div class="block block-boxes block-boxes-id-menu_border_security">
# <div class="content"><div class="boxes-box" id="boxes-box-menu_border_security"><div class="boxes-box-content"><p><a href="/border-security/along-us-borders/history">Border Patrol History</a></p><p><a href="/border-security/along-us-borders/strategic-plan">Strategic Plan</a></p><p><a href="/border-security/along-us-borders/border-patrol-sectors">Border Patrol Sectors</a></p></div></div></div>
# </div><!-- /.block -->
# <div class="block block-views block-views-id-menu_featured_item-block_19">
# <div class="content"><div class="view view-menu-featured-item view-id-menu_featured_item view-display-id-block_19 view-dom-id-9e37cff013e9a9d608d79be79aef83a9">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# ...
# <div class="region-inner region-sidebar-first-inner">
# <section class="block block-menu-block block-4 block-menu-block-4 odd" id="block-menu-block-4">
# <div class="block-inner clearfix">
# <h2 class="block-title"><a class="active-trail" href="/newsroom">Newsroom</a></h2>
# <div class="content clearfix">
# <div class="menu-block-wrapper menu-block-4 menu-name-main-menu parent-mlid-621 menu-level-1">
# <ul class="menu"><li class="first leaf menu-mlid-2140"><a href="/newsroom/news/advisories">Advisories</a></li>
# <li class="leaf menu-mlid-646"><a href="/newsroom/media-releases/all" title="">Media Releases</a></li>
# <li class="leaf menu-mlid-2121"><a href="/newsroom/photo-gallery" title="">Photo Gallery</a></li>
# <li class="leaf menu-mlid-2125"><a href="/newsroom/video-gallery" title="">Video Gallery</a></li>
# <li class="leaf menu-mlid-2123"><a href="/newsroom/press">Press Officers</a></li>
# <li class="collapsed menu-mlid-2287"><a href="/newsroom/publications">Publications</a></li>
# <li class="leaf menu-mlid-39638"><a href="/newsroom/social-media-directory">Social Media Directory</a></li>
# <li class="leaf menu-mlid-2393"><a href="/newsroom/speeches" title="">Speeches/Statements</a></li>
# <li class="leaf menu-mlid-15777"><a href="/newsroom/news/news-from-cbp" title="">Spotlights</a></li>
# <li class="expanded active-trail menu-mlid-1912"><a class="active-trail" href="/newsroom/stats">Stats and Summaries</a><ul class="menu"><li class="first leaf menu-mlid-38766"><a href="/newsroom/stats/typical-day-fy2020">On a Typical Day</a></li>
# <li class="leaf menu-mlid-38734"><a href="/newsroom/stats/cbp-enforcement-statistics">CBP Enforcement Statistics</a></li>
# <li class="leaf active-trail menu-mlid-38762"><a class="active-trail" href="/newsroom/stats/southwest-land-border-encounters">Southwest Land Border Encounters</a></li>
# <li class="leaf menu-mlid-39931"><a href="https://www.cbp.gov/newsroom/stats/nationwide-encounters" title="">Nationwide Encounters</a></li>
# <li class="leaf menu-mlid-38731"><a href="/newsroom/stats/assaults-use-force">Assaults and Use of Force Statistics</a></li>
# <li class="leaf menu-mlid-39639"><a href="/newsroom/stats/southwest-land-border-encounters-by-component">Southwest Land Border Encounters (By Component)</a></li>
# <li class="leaf menu-mlid-29265"><a href="/newsroom/stats/trade">Trade Statistics</a></li>
# <li class="last leaf menu-mlid-26432"><a href="/newsroom/stats/webmetrics">Web Performance Metrics</a></li>
# </ul></li>
# <li class="last leaf menu-mlid-33978"><a href="/newsroom/coronavirus">COVID-19</a></li>
# </ul></div>
# </div>
# </div>
# </section> </div>
# </aside><div class="grid-6 region region-content" id="region-content">
# <div class="region-inner region-content-inner">
# <a id="main-content"></a>
# <h1 class="title" id="page-title">U.S. Border Patrol Southwest Border Apprehensions by Sector</h1>
# <div class="block block-block block-45 block-block-45 odd block-without-title" id="block-block-45">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <script type="text/javascript">
# <!--//--><![CDATA[// ><!--
#
# /*<![CDATA[*/
# (function() {
# var sz = document.createElement('script'); sz.type = 'text/javascript'; sz.async = true;
# sz.src = '//siteimproveanalytics.com/js/siteanalyze_6034474.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sz, s);
# })();
# /*]]]]><![CDATA[>*/
#
# //--><!]]>
# </script> </div>
# </div>
# </div><div class="block block-block block-54 block-block-54 even block-without-title" id="block-block-54">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <script>
# <!--//--><![CDATA[// ><!--
#
# jQuery(document).ready(function() {
#   jQuery("#region-content").wrap("<main>");
# });
#
# //--><!]]>
# </script> </div>
# </div>
# </div><div class="block block-print-ui block-print-links block-print-ui-print-links odd block-without-title" id="block-print-ui-print-links">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <span class="print_html"><a class="print-page" href="https://www.cbp.gov/print/365977" onclick="window.open(this.href); return false" rel="nofollow" title="Display a printer-friendly version of this page."><img alt="Printer-friendly version" class="print-icon print-icon-margin" height="16px" src="https://www.cbp.gov/profiles/cbp_gov/modules/contrib/print/icons/print_icon.png" title="Printer-friendly version" width="16px"/>Printer-friendly version</a></span> </div>
# </div>
# </div><div class="block block-system block-main block-system-main even block-without-title" id="block-system-main">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <article class="node node-accordion-page node-published node-not-promoted node-not-sticky odd clearfix" id="node-accordion-page-365977">
# <div class="content clearfix">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span style="color:#c0392b;"><strong>NOTE:</strong></span> This webpage is no longer updated. For updated monthly encounter information, please visit <a href="/newsroom/stats/southwest-land-border-encounters-by-component">the Southwest Land Border Encounters (By Component)</a> dashboard.</p><hr/><h2><strong>Southwest Border Unaccompanied Children (0-17 yr old) Encounters<sup style="font-size: smaller; vertical-align: super;">1</sup></strong></h2><p>Comparisons below reflect YTD2020 compared to YTD2021.</p><table border="1" cellpadding="1" cellspacing="1" style="width: 100%;" summary="UAC apprehensions by Sector"><thead><tr><th colspan="4" scope="col" style="text-align: center;">Unaccompanied Children Encounters by Sector</th></tr><tr><th scope="col" style="text-align: left;">Sector</th><th scope="col" style="text-align: center;">FY20 TD MAR</th><th scope="col" style="text-align: center;">FY21 TD MAR</th><th scope="col" style="text-align: center;">% Change<br/>FY20 TD MAR to FY21 TD MAR</th></tr></thead><tbody><tr><td>Big Bend</td><td style="text-align: center;">254</td><td>           845</td><td style="text-align: center;">233%</td></tr><tr><td>Del Rio</td><td style="text-align: center;">1,166</td><td>        3,431</td><td style="text-align: center;">194%</td></tr><tr><td>El Centro</td><td style="text-align: center;">715</td><td>        1,047</td><td style="text-align: center;">46%</td></tr><tr><td>El Paso</td><td style="text-align: center;">2,598</td><td>        8,636</td><td style="text-align: center;">232%</td></tr><tr><td>Laredo</td><td style="text-align: center;">1,607</td><td>        2,045</td><td style="text-align: center;">27%</td></tr><tr><td>Rio Grande</td><td style="text-align: center;"> 6,351</td><td>      20,964</td><td style="text-align: center;">230%</td></tr><tr><td>San Diego</td><td style="text-align: center;">1,040</td><td>        1,888</td><td style="text-align: center;">82%</td></tr><tr><td>Tucson</td><td style="text-align: center;">3,859</td><td>        7,079</td><td style="text-align: center;">83%</td></tr><tr><td>Yuma</td><td style="text-align: center;">506</td><td>        1,707</td><td style="text-align: center;">237%</td></tr><tr><td><strong>USBP Southwest Border Total</strong></td><td style="text-align: center;">18,096</td><td>      47,642</td><td style="text-align: center;">163%</td></tr></tbody></table><p><sup style="font-size: smaller; vertical-align: super;">1 </sup>Beginning in March FY20,  USBP Encounters statistics include both Title 8  Apprehensions and Title 42 Expulsions. To learn more, visit: <a href="/newsroom/stats/cbp-enforcement-statistics/title-8-and-title-42-statistics">Title-8-and-Title-42-Statistics</a></p><h2><strong>Southwest Border Family Unit* Encounters<sup style="font-size: smaller; vertical-align: super;">1</sup></strong></h2><p>Comparisons below reflect YTD2020 compared to YTD2021.</p><table border="1" cellpadding="1" cellspacing="1" style="width: 100%;" summary="Family Unit Apprehensions by Sector"><thead><tr><th colspan="4" scope="col">Family Unit* Encounters by Sector</th></tr><tr><th><strong>Sector</strong></th><th scope="col" style="text-align: center;">FY20 TD MAR</th><th scope="col" style="text-align: center;">FY21 TD MAR</th><th scope="col" style="text-align: center;">% Change<br/>FY20 TD MAR to FY21 TD MAR</th></tr></thead><tbody><tr><td>Big Bend</td><td style="text-align: center;">280</td><td style="text-align: center;">           453</td><td style="text-align: center;">62%</td></tr><tr><td>Del Rio</td><td style="text-align: center;">4,677</td><td style="text-align: center;">       11,148</td><td style="text-align: center;">138%</td></tr><tr><td>El Centro</td><td style="text-align: center;">795</td><td style="text-align: center;">           939</td><td style="text-align: center;">18%</td></tr><tr><td>El Paso</td><td style="text ...
# <div class="clearfix">
# <nav class="links node-links clearfix"></nav>
# </div>
# </article> </div>
# </div>
# </div><div class="block block-cbp-social-links block-cbp-social-links block-cbp-social-links-cbp-social-links odd block-without-title" id="block-cbp-social-links-cbp-social-links">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <div class="socialImagesDiv" style="cursor: pointer;" tabindex="0">
# <div id="showThisPageContainer"><span class="icon-show"><img alt="Click to expand and share this page on social networks" src="/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_share.png"/></span><span id="showText">Share This Page.</span></div>
# <div class="social-images">
# <a href="https://www.facebook.com/sharer/sharer.php?u=UNIURL" target="_blank"><img alt="Facebook Icon" src="https://www.cbp.gov/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_facebook.png"/></a>
# <a href="https://twitter.com/intent/tweet?text=U.S.+Border+Patrol+Southwest+Border+Apprehensions+by+Sector&amp;url=UNIURL&amp;via=cbp" target="_blank"><img alt="Twitter Icon" src="https://www.cbp.gov/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_twitter.png"/></a>
# <a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=UNIURL&amp;title=U.S. Border Patrol Southwest Border Apprehensions by Sector&amp;summary=&amp;source=" target="_blank"><img alt="LinkedIn Icon" src="https://www.cbp.gov/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_linkedin.png"/></a>
# <a href="https://www.tumblr.com/share/link?url=UNIURL&amp;name=U.S. Border Patrol Southwest Border Apprehensions by Sector&amp;description=" target="_blank"><img alt="Tumblr Icon" src="https://www.cbp.gov/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_tumblr.png"/></a>
# <a href="mailto:?subject=U.S. Border Patrol Southwest Border Apprehensions by Sector&amp;body=UNIURL" target="_blank"><img alt="Mailto Icon" src="https://www.cbp.gov/profiles/cbp_gov/themes/cbp_gov_theme/images/social/icon_mailto.png"/></a>
# </div>
# </div> </div>
# </div>
# </div> </div>
# </div><aside class="grid-3 region region-sidebar-second" id="region-sidebar-second">
# <div class="region-inner region-sidebar-second-inner">
# <div class="block block-views block-c0ef8da322bdc0b45cb7d286356f4089 block-views-c0ef8da322bdc0b45cb7d286356f4089 odd block-without-title" id="block-views-c0ef8da322bdc0b45cb7d286356f4089">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <div class="view view-cbp-shared-fields-view view-id-cbp_shared_fields_view view-display-id-related_content_block_revision view-dom-id-f329a9bf5517f06f37a5495b1b59515b">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <div class="views-field views-field-field-related-content-group-revision-id"> <div class="field-content"><div class="item-list"><ul><li class="first last"><div class="field-collection-view clearfix view-mode-full field-collection-view-final"><div class="entity entity-field-collection-item field-collection-item-field-related-content-group">
# <div class="content">
# <div class="field field-name-field-related-content-heading field-type-text field-label-hidden"><div class="field-items"><div class="field-item even">Previous Year Statistics</div></div></div><div class="field field-name-field-related-content field-type-node-reference field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2020">U.S. Border Patrol Southwest Border Apprehensions by Sector Fiscal Year 2020</a></div><div class="field-item odd"><a href="/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2019">U.S. Border Patrol Southwest Border Apprehensions by Sector Fiscal Year 2019</a></div><div class="field-item even"><a href="/newsroom/stats/usbp-sw-border-apprehensions">U.S. Border Patrol Southwest Border Apprehensions by Sector FY2018</a></div><div class="field-item odd"><a href="/newsroom/stats/usbp-sw-border-apprehensions-fy2017">U.S. Border Patrol Southwest Border Apprehensions by Sector FY2017</a></div></div></div> </div>
# </div>
# </div></li></ul></div></div> </div> </div>
# </div>
# </div> </div>
# </div>
# </div> </div>
# </aside> </div>
# </div></section>
# <footer class="section section-footer" id="section-footer">
# <div class="zone-wrapper zone-footer-wrapper clearfix" id="zone-footer-wrapper">
# <div class="zone zone-footer clearfix container-12" id="zone-footer">
# <div class="grid-12 region region-footer-first" id="region-footer-first">
# <div class="region-inner region-footer-first-inner">
# <div class="block block-boxes block-boxes-simple block-footer-seal block-boxes-footer-seal odd block-without-title" id="block-boxes-footer-seal">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <div class="boxes-box" id="boxes-box-footer_seal"><div class="boxes-box-content"><ul><li><a href="http://cbp.gov/about">About CBP</a></li><li><a href="http://cbp.gov/newsroom">Newsroom</a></li><li><a href="http://cbp.gov/travel">Travel</a></li></ul><div><img alt="U.S. Department of Homeland Security" height="100" src="/profiles/cbp_gov/themes/cbp_gov_theme/logo.png" width="100"/></div><ul><li><a href="http://cbp.gov/trade">Trade</a></li><li><a href="http://cbp.gov/border-security">Border Security</a></li><li><a href="http://cbp.gov/careers">Careers</a></li></ul></div></div> </div>
# </div>
# </div><div class="block block-boxes block-boxes-simple block-footer-site-links block-boxes-footer-site-links even block-without-title" id="block-boxes-footer-site-links">
# <div class="block-inner clearfix">
# <div class="content clearfix">
# <div class="boxes-box" id="boxes-box-footer_site_links"><div class="boxes-box-content"><ul><li><a href="/site-policy-notices/accessibility">Accessibility</a></li><li><a href="/newsroom/publications/performance-accountability-financial">Accountability</a></li><li><a href="https://www.cbp.gov/dhs-component-websites">DHS Components</a></li><li><a href="/site-policy-notices/foia">FOIA</a></li><li><a href="/newsroom/publications/forms">Forms</a></li><li><a href="https://www.oig.dhs.gov/">Inspector General</a></li><li><a href="/about/eeo-diversity/no-fear-act">No FEAR Act</a></li><li><a href="/site-policy-notices/privacy-statement">Privacy</a></li><li><a href="/site-policy-notices">Site Policies</a></li><li><a href="https://www.whitehouse.gov/">The White House</a></li><li><a href="http://usa.gov/">USA.gov</a></li><li><a href="/plugin-information">Plug-ins</a></li></ul></div></div> </div>
# </div>
# </div> </div>
# </div> </div>
# </div></footer> </div> <div class="region region-page-bottom" id="region-page-bottom">
# <div class="region-inner region-page-bottom-inner">
# </div>
# </div><script src="https://www.cbp.gov/sites/default/files/js/js_9GWEvmxvASfmJwceTA7AKz78sYf7GWSLF4Na7qBkYu8.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var usasearch_config = { siteHandle:'cbpgov' };
# var script = document.createElement('script');
# script.type = 'text/javascript';
# script.src = '//search.usa.gov/javascripts/remote.loader.js';
# document.getElementsByTagName('head')[0].appendChild(script);
#
# //--><!]]>
# </script>
# </body>

# %%
# pd.read_html(data_FY2020_url)

# %%
# Open with GET method
resp = requests.get(data_FY2021_url)

# %%
print(resp)
# Out:
# <Response [200]>

# %%
# def websites():
#     # The websites we want to scrape
#     # Need to put these into a dictionary/list to call later, not sure which one just yet
#     data_FY2021_url = "https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters/usbp-sw-border-apprehensions"
#     data_FY2020_url = "https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2020"
#     data_FY2019_url = "https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2019"
#     data_FY2018_url = "https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions"
#     data_FY2017_url = "https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions-fy2017"
    
#     # Open with GET method
#     resp = requests.get(data_FY2021_url)
    
#     # http_response 200 means OK status
#     if resp.status_code == 200:
#         print("Successfully opened webpage")
#         print("Here is your webpage:-\n")
        
#         # We need a parser, Python built-in HTML parser will work
#         soup = BeautifulSoup(resp.text,'html.parser')
        
#     else:
#         print(f"Error, your response code was {resp.status_code}")
# websites()

# %%
def websites_data(URL):
    # The websites we want to scrape
    # Need to put these into a dictionary/list to call later, not sure which one just yet
    data_FY2021_url = "https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters/usbp-sw-border-apprehensions"
    data_FY2020_url = "https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2020"
    data_FY2019_url = "https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2019"
    data_FY2018_url = "https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions"
    data_FY2017_url = "https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions-fy2017"
    
    if resp.status_code == 200:
        print("Successfully opened webpage")
        print("Here is your webpage:-\n")
        # Open with GET method
        resp = requests.get(URL)

# %%
websites
# Out:
# ['https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters/usbp-sw-border-apprehensions',
#  'https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2020',
#  'https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2019',
#  'https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions',
#  'https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions-fy2017']

# %%
def websites():
    # The websites we want to scrape
    # Need to put these into a dictionary/list to call later, not sure which one just yet
    data_FY2021_url = "https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters/usbp-sw-border-apprehensions"
    data_FY2020_url = "https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2020"
    data_FY2019_url = "https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2019"
    data_FY2018_url = "https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions"
    data_FY2017_url = "https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions-fy2017"
    
    # Open with GET method
    resp = requests.get(data_FY2021_url)
    
    # http_response 200 means OK status
    if resp.status_code == 200:
        print("Successfully opened webpage")
        print("Here is your webpage:-\n")
        
        # We need a parser, Python built-in HTML parser will work
        soup = BeautifulSoup(resp.text,'html.parser')
        
        # text_list is the list that contains all the text
        text_list = soup.find("ul",{"class":"searchNews"})
        print(text_list)
        
        # Now we want to print only the text part of the anchor.
        # Find all the elements of a, i.e. anchor
#         for i in text_list.findAll("dt"):
#             print(i.text)
    else:
        print("Error")
websites()
# Out:
# Successfully opened webpage
# Here is your webpage:-
#
# None

# %%
soup = BeautifulSoup(resp.text,'html.parser')
soup.head.title
# Out:
# <title>U.S. Border Patrol Southwest Border Apprehensions by Sector | U.S. Customs and Border Protection</title>

# %%
soup.body.a.text
# Out:
# 'Skip to main content'

# %%
soup.body.p.b     # returns <b>Body's title</b>

# %%
soup.body.div
# Out:
# <div id="skip-link">
# <a class="element-invisible element-focusable" href="#main-content">Skip to main content</a>
# </div>

# %%
soup.body.thead
# Out:
# <thead><tr><th colspan="4" scope="col" style="text-align: center;">Unaccompanied Children Encounters by Sector</th></tr><tr><th scope="col" style="text-align: left;">Sector</th><th scope="col" style="text-align: center;">FY20 TD MAR</th><th scope="col" style="text-align: center;">FY21 TD MAR</th><th scope="col" style="text-align: center;">% Change<br/>FY20 TD MAR to FY21 TD MAR</th></tr></thead>

# %%
soup.body.tbody
# Out:
# <tbody><tr><td>Big Bend</td><td style="text-align: center;">254</td><td>           845</td><td style="text-align: center;">233%</td></tr><tr><td>Del Rio</td><td style="text-align: center;">1,166</td><td>        3,431</td><td style="text-align: center;">194%</td></tr><tr><td>El Centro</td><td style="text-align: center;">715</td><td>        1,047</td><td style="text-align: center;">46%</td></tr><tr><td>El Paso</td><td style="text-align: center;">2,598</td><td>        8,636</td><td style="text-align: center;">232%</td></tr><tr><td>Laredo</td><td style="text-align: center;">1,607</td><td>        2,045</td><td style="text-align: center;">27%</td></tr><tr><td>Rio Grande</td><td style="text-align: center;"> 6,351</td><td>      20,964</td><td style="text-align: center;">230%</td></tr><tr><td>San Diego</td><td style="text-align: center;">1,040</td><td>        1,888</td><td style="text-align: center;">82%</td></tr><tr><td>Tucson</td><td style="text-align: center;">3,859</td><td>        7,079</td><td style="text-align: center;">83%</td></tr><tr><td>Yuma</td><td style="text-align: center;">506</td><td>        1,707</td><td style="text-align: center;">237%</td></tr><tr><td><strong>USBP Southwest Border Total</strong></td><td style="text-align: center;">18,096</td><td>      47,642</td><td style="text-align: center;">163%</td></tr></tbody>

# %%
# URLs from the U.S. Customs and Border Protection website with data tables 

# def websites():
#     # The websites we want to scrape
#     # Need to put these into a dictionary/list to call later, not sure which one just yet
#     data_FY2021_url = "https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters/usbp-sw-border-apprehensions"
#     data_FY2020_url = "https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2020"
#     data_FY2019_url = "https://www.cbp.gov/newsroom/stats/sw-border-migration/usbp-sw-border-apprehensions-fy2019"
#     data_FY2018_url = "https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions"
#     data_FY2017_url = "https://www.cbp.gov/newsroom/stats/usbp-sw-border-apprehensions-fy2017"
    
#     # Open with GET method
#     resp = requests.get(data_FY2021_url)
    
#     # http_response 200 means OK status
#     if resp.status_code == 200:
#         print("Successfully opened webpage")
#         print("Here is your webpage:-\n")
        
#         # We need a parser, Python built-in HTML parser will work
#         soup = BeautifulSoup(resp.text,'html.parser')
        
#         # text_list is the list that contains all the text
#         text_list = soup.find("ul",{"class":"searchNews"})
        
#         # Now we want to print only the text part of the anchor.
#         # Find all the elements of a, i.e. anchor
#         for i in text_list.findAll("a"):
#             print(i.text)
#     else:
#         print("Error")
# websites()

# # Import html file using BeautifulSoup
# with open(data_FY2021_url) as f:
#     # read file
#     content = f.read()
#     # parse html
#     soup = soup(content, 'html.parser')
#     # print Title tag
#     print(soup.title)

# HTMLParser.feed(' ',data_FY2021_url)

# # urllib.request.urlopen(url).read()

# webbrowser.open(data_FY2021_url)

# res = requests.get(data_FY2021_url)

# type(res)
# res.status_code == requests.codes.ok
# len(res.text)
# print(res.text[:250])

# res.raise_for_status()
# noStarchSoup = soup(res.text)
# type(noStarchSoup)


# soup_file = open(data_FY2021_url)
# soup_pull = soup(data_FY2021_url.read())
